# %%
import pandas as pd
import numpy as np
import pickle

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.ensemble import GradientBoostingRegressor
from customTransformers import (ColumnSelectTransformer, DiagnosisFrameTransformer, 
                                ColumnMergeTransformer
                               )

# %%
X_train, y_train = pd.read_pickle('./data/pickle/preproc/df_patient_admit_icu_notes__20210206_singleICUSTAY_TRAIN_final.pkl')

# %%
X_train['TEXT'].iloc[67]
# Out:
# '  cta chest ww crecons non coronary cta abd pelvis clip clip number radiology reason eval known aortic dissection changes progression pr admitting diagnosis thoracic dissection contrast omnipaque amt hospital medical condition year old woman aortic dissection reason examination eval known aortic dissection changes progression prior imaging please perform contraindications iv contrast wet read mlhh sun stable appearance type dissection extending past sca takeoff prox iliac unchanged intramural hematoma level aortic arch false lumen primarily supplies renal subtle hypoperfusion kidney infarct new tiny nonhemorrhagic pleural pericardial effusions inc active long segment acute inflammation rlq distal ileum chronic ibc changes ti segments colon wet read version wet read version mlhh sun stable appearance type dissection extending past sca takeoff prox iliac unchanged intramural hematoma level aortic arch false lumen primarily supplies renal subtle hypoperfusion kidney infarct inc active long segment acute inflammation rlq distal ileum chronic ibc changes ti segments colon final report indication year old female crohn disease acute onset chest back pain type aortic dissection admitted blood pressure monitoring comparison technique helical mdct images acquired torso following uneventful administration ml intravenous omnipaque using long dissection protocol mm axial mm coronal mm sagittal multiplanar reformats generated findings chest small bilateral nonhemorrhagic layering pleural effusions developed adjacent compressive atelectasis seen mild apical predominant centrilobular emphysema diffuse peribronchial wall thickening scattered centrilobular nodules suggesting aspiration unchanged mm ground glass nodule apical segment right upper lobe over cta chest ww crecons non coronary cta abd pelvis clip clip number radiology reason eval known aortic dissection changes progression pr admitting diagnosis thoracic dissection contrast omnipaque amt final report cont heart normal size small pericardial effusion slightly increased central pulmonary arteries unremarkable pathologically enlarged axillary hilar medistinal lymph nodes mm hypodensity along posterior right thyroid lobe may represent exophytic thyroid nodule parathyroid adenoma abdomen diffuse fatty infiltration liver gallbladder surgically absent trace retained fluid gallbladder fossa pancreas enhances normally intra extra hepatic biliary ductal dilation spleen normal size adrenal glands remain full without discrete nodularity suggestive hyperplasia kidneys enhance homogeneously subtly delayed perfusion left renal masses hydronephrosis stomach proximal small bowel normal noted cm long segment actively inflamed distal ileum right lower quadrant region demonstrates mural thickening mucosal hyperenhancement dilation vasa recta comb sign however evidence intramural abscess extraluminal fluid collection enteric fistula several additional areas intramural fat deposition within terminal ileum compatible chronic inflammatory bowel disease changes ventral wall hernia repair residual fat stranding surrounding fluid collections subcutaneous air noted left supraumbilical region likely recent injection pelvis noted hyperdense material within base mid portion appendix absence oral contrast administration may represent appendicolith versus inspissated secretions however appendiceal tip filled air significant surrounding wall thickening fat stranding suggest acute inflammation note made intramural fat deposition within cecum hepatic flexure transverse colon splenic flexure compatible chronic inflammatory bowel disease large amount retained fecal material descending sigmoid colon well rectal impaction noted cm cyst right ovary uterus left ovary normal bladder distal ureters unremarkable trace free fluid pelvis scattered prominent retroperitoneal nodes measure mm over cta chest ww crecons non coronary cta abd pelvis clip clip number radiology reason eval known aortic dissection changes progression pr a ...

# %%
file = './data/pickle/models/gradientboost__LOS__20210215.pkl'
model_data = pickle.load(open(file,'rb'))

# %%
model_data['estimator'].best_estimator_.named_steps.reg.n_features_
# Out:
# 10123

# %%
best = model_data['estimator'].best_estimator_

# %%
los_dft = best.named_steps.features.transformer_list[1][1].named_steps.dft

# %%
file = './data/pickle/models/gradientboost__LOS__20210305_forFlask_from_20210215.pkl'
pickle.dump((los_dft, best), open(file,'wb'))

# %%
model_data['estimator'].best_params_
# Out:
# {'features__text_feats__count__max_features': 10000,
#  'features__text_feats__count__min_df': 0.0001,
#  'features__text_feats__count__ngram_range': (1, 2),
#  'features__text_feats__tfid__norm': 'l2',
#  'reg__criterion': 'mse',
#  'reg__loss': 'ls'}

# %%
count = CountVectorizer(max_features=10000, min_df=0.0001, ngram_range=(1,2))
tfidf = TfidfTransformer(norm='l2')
reg = GradientBoostingRegressor(criterion='mse', loss='ls')

# %%
cols = ['GENDER','ADMISSION_TYPE','ADMISSION_LOCATION','INSURANCE','LANGUAGE',
       'RELIGION','MARITAL_STATUS','ETHNICITY']
num_cols = ['ADMIT_AGE']

ohe = ColumnTransformer([('categorical', OneHotEncoder(handle_unknown='ignore'), cols)])
demog_feats = FeatureUnion([
    ('stdscl', ColumnTransformer([('numerical', StandardScaler(), num_cols)])),
    ('ohe',  ohe)
])

text_feats = Pipeline([
    ('dft', DiagnosisFrameTransformer(['DIAGNOSIS'])),
    ('cmt', ColumnMergeTransformer(['DIAGNOSIS','TEXT'])),
    ('cst', ColumnSelectTransformer('DIAGNOSIS_TEXT')),
    ('count', count),
    ('tfidf', tfidf)
])

feats_union = FeatureUnion([
    ('demog_feats', demog_feats),
    ('text_feats', text_feats)
])

lin_pipe = Pipeline([
    ('features', feats_union),
    ('reg', reg)
])

lin_est = lin_pipe.fit(X_train,X_train['LOS'])

# %%
X_test, y_test = pd.read_pickle('./data/pickle/preproc/df_patient_admit_icu_notes__20210206_singleICUSTAY_TEST_final.pkl')

# %%
x_test = X_test.iloc[0]

# %%
best.predict(x_test.to_frame().transpose())[0]
# Out:
# 3.9693878474247333

# %%
x_test.to_frame().transpose()
# Out:
#       SUBJECT_ID HADM_ID ICUSTAY_ID           ADMITTIME           CHARTTIME  \
# 67659      41738  184992     249970 2171-01-07 13:56:59 2171-01-07 20:19:00
#
#                    INTIME GENDER ADMIT_AGE ADMISSION_TYPE  \
# 67659 2171-01-09 11:03:58      M        84      EMERGENCY
#
#               ADMISSION_LOCATION  ... RELIGION MARITAL_STATUS ETHNICITY  \
# 67659  CLINIC REFERRAL/PREMATURE  ...   JEWISH        WIDOWED     WHITE
#
#                                                DIAGNOSIS TEXT    DBSOURCE  \
# 67659  WORSENING DYSPNEA ON EXERTION;AORTIC STENOSIS\...       metavision
#
#           LOS DAYS_EVENT_TO_ICU   ICU_URGENCY SAMEDAY_EVENT_TO_ICU
# 67659  3.0567           1.87984  questionable                    0
#
# [1 rows x 22 columns]

# %%
X_test.columns
# Out:
# Index(['SUBJECT_ID', 'HADM_ID', 'ICUSTAY_ID', 'ADMITTIME', 'CHARTTIME',
#        'INTIME', 'GENDER', 'ADMIT_AGE', 'ADMISSION_TYPE', 'ADMISSION_LOCATION',
#        'INSURANCE', 'LANGUAGE', 'RELIGION', 'MARITAL_STATUS', 'ETHNICITY',
#        'DIAGNOSIS', 'TEXT', 'DBSOURCE', 'LOS', 'DAYS_EVENT_TO_ICU',
#        'ICU_URGENCY', 'SAMEDAY_EVENT_TO_ICU'],
#       dtype='object')

# %%
y_pred = lin_est.predict(X_test)

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource, Legend, HoverTool
from bokeh.palettes import Spectral4
from bokeh.layouts import row

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3222">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.transform import factor_cmap
from bokeh.palettes import Spectral4

p1 = figure(title="LOS Model Performance", tooltips='', plot_height=400, plot_width=500)

source = ColumnDataSource({
    'x': X_test['LOS'],
    'y': y_pred,
    'groups': X_test['ICU_URGENCY']
})

labels = ['stable','questionable','urgent','immediate']
p1.circle('x', 'y', fill_color=None, 
         line_color=factor_cmap('groups', Spectral4, labels),
         size=5, source=source, legend_field='groups',
          alpha=0.2, selection_alpha=0.8)

p1.legend.location = "top_left"
p1.legend.click_policy="hide"
p1.xaxis.axis_label = 'True LOS'
p1.yaxis.axis_label = 'Predicted LOS'
p1.title.text_font_size = '16pt'
p1.yaxis.axis_label_text_font_size = '14pt'
p1.xaxis.axis_label_text_font_size = '14pt'
p1.yaxis.major_label_text_font_size = '11pt'
p1.xaxis.major_label_text_font_size = '11pt'

from sklearn.metrics import mean_squared_error

rmse = []
for urg in  X_test['ICU_URGENCY'].unique():
    mask = X_test['ICU_URGENCY']==urg
    rmse.append((mean_squared_error(X_test.LOS[mask], y_pred[mask]))**1/2)
    
factors = ['stable','questionable','urgent','immediate']
source = ColumnDataSource(data=dict(factors=factors, rmse=rmse, color=Spectral4))

hover = HoverTool(
  tooltips=[
      ("Level", "@factors"),
      ("RMSE", "@rmse"),
  ]
)

p2 = figure(x_range=factors, plot_height=400,
      plot_width=500, tools=[hover], title="RMSE by Urgency Level")

p2.vbar(x='factors', top='rmse', color='color', width=0.4, source=source)

p2.title.text_font_size = '16pt'
p2.yaxis.axis_label_text_font_size = '14pt'
p2.yaxis.major_label_text_font_size = '11pt'
p2.xaxis.major_label_text_font_size = '11pt'
p2.xgrid.grid_line_color = None
p2.y_range.start = 0
p2.yaxis.axis_label = 'RMSE'
layout = row(p1, p2)
show(layout)
# Out:
#   <div class="bk-root" id="d73be378-2437-4eca-9113-18bf3830fbe1" data-root-id="6302"></div>

# %%
from bokeh.transform import factor_cmap
from bokeh.palettes import Spectral4
from sklearn.metrics import mean_squared_error
from bokeh.models import BoxSelectTool, BoxZoomTool, ResetTool
from bokeh.models import CheckboxGroup, CustomJS

hover1 = HoverTool(
  tooltips=[
      ("True", "@x"),
      ("Predicted", "@y"),
  ]
)

hover2 = HoverTool(
  tooltips=[
      ("Level", "@x"),
      ("RMSE", "@y"),
  ]
)

p1 = figure(title="LOS Model Performance", tools=[hover1, BoxSelectTool(), BoxZoomTool(), ResetTool()], plot_height=400, plot_width=500)
p2 = figure(x_range=factors, plot_height=400,
      plot_width=500, tools=[hover2, BoxSelectTool(), ResetTool()], title="RMSE by Urgency Level")

labels = ['stable','questionable','urgent','immediate']

rmse = []
sources1 = {}
sources2= {}
circles = {}
bars = {}
for ix,urg in  enumerate(labels):
    mask = X_test['ICU_URGENCY']==urg
    sources1[urg] = ColumnDataSource({
        'x': X_test.LOS[mask],
        'y': y_pred[mask],
    })
    sources2[urg] = ColumnDataSource({
        'x': [urg],
        'y': [(mean_squared_error(X_test.LOS[mask], y_pred[mask]))**1/2]
    })
    circles[urg] = p1.circle('x', 'y', fill_color=None, alpha=0.4, selection_alpha=0.8,
         selection_fill_color=Spectral4[ix], line_color=Spectral4[ix], size=5, source=sources1[urg], legend_label=urg)
    bars[urg] = p2.vbar(x='x', top='y', color=Spectral4[ix], width=0.4, source=sources2[urg])

    
checkbox = CheckboxGroup(labels=labels,
                         active=[0, 1, 2, 3], width=100)

callback = CustomJS(args=dict(circles=circles, bars=bars, checkbox=checkbox), code="""
circles['stable'].visible = 0 in checkbox.active;
circles['questionable'].visible = 1 in checkbox.active;
circles['urgent'].visible = 2 in checkbox.active;
circles['immediate'].visible = 3 in checkbox.active;
bars['stable'].visible = 0 in checkbox.active;
bars['questionable'].visible = 1 in checkbox.active;
bars['urgent'].visible = 2 in checkbox.active;
bars['immediate'].visible = 3 in checkbox.active;
""")
checkbox.js_on_change('active', callback)

p1.legend.location = "top_left"
p1.xaxis.axis_label = 'True LOS (days)'
p1.yaxis.axis_label = 'Predicted LOS (days)'
p1.title.text_font_size = '16pt'
p1.yaxis.axis_label_text_font_size = '14pt'
p1.xaxis.axis_label_text_font_size = '14pt'
p1.yaxis.major_label_text_font_size = '11pt'
p1.xaxis.major_label_text_font_size = '11pt'

p2.title.text_font_size = '16pt'
p2.yaxis.axis_label_text_font_size = '14pt'
p2.yaxis.major_label_text_font_size = '11pt'
p2.xaxis.major_label_text_font_size = '11pt'
p2.xgrid.grid_line_color = None
p2.y_range.start = 0
p2.yaxis.axis_label = 'RMSE'

layout = row(checkbox, p1, p2)
show(layout)
# Out:
#   <div class="bk-root" id="d7fffbee-2006-4fce-a102-a019a5d742b2" data-root-id="26736"></div>

# %%
ex_dict = {'immediate': 8065, 'questionable': 10545,
          'stable': 68757,'urgent': 10547}

# %%
X_test_reset = X_test.reset_index()

# %%
X_test_reset[X_test_reset['index']==ex_dict['stable']]
# Out:
#      index SUBJECT_ID   HADM_ID ICUSTAY_ID           ADMITTIME  \
# 110  68757      43320  154851.0     233289 2128-08-10 07:15:00
#
#               CHARTTIME              INTIME GENDER ADMIT_AGE ADMISSION_TYPE  \
# 110 2128-08-14 10:08:00 2128-09-07 21:56:52      M        74       ELECTIVE
#
#      ... MARITAL_STATUS ETHNICITY           DIAGNOSIS  \
# 110  ...        MARRIED     WHITE  bladder cancer sda
#
#                                                   TEXT    DBSOURCE     LOS  \
# 110    portable abdomen clip clip number radiology ...  metavision  0.8666
#
#     DAYS_EVENT_TO_ICU ICU_URGENCY SAMEDAY_EVENT_TO_ICU  \
# 110         24.492269      stable                    0
#
#                                         DIAGNOSIS_TEXT
# 110  bladder cancer sda  portable abdomen clip clip...
#
# [1 rows x 24 columns]

# %%
X_test_reset[X_test_reset['index']==ex_dict['questionable']]
# Out:
#       index SUBJECT_ID   HADM_ID ICUSTAY_ID           ADMITTIME  \
# 8423  10545       5285  127903.0     259613 2202-09-22 07:15:00
#
#                CHARTTIME              INTIME GENDER ADMIT_AGE ADMISSION_TYPE  \
# 8423 2202-09-22 15:53:00 2202-09-24 12:02:26      F        60       ELECTIVE
#
#       ... MARITAL_STATUS ETHNICITY  \
# 8423  ...        MARRIED     WHITE
#
#                                               DIAGNOSIS  \
# 8423  coronary artery disease sda aortic valve repla...
#
#                                                    TEXT DBSOURCE     LOS  \
# 8423    carotid series complete clip clip number rad...  carevue  4.2838
#
#      DAYS_EVENT_TO_ICU   ICU_URGENCY SAMEDAY_EVENT_TO_ICU  \
# 8423          1.839884  questionable                    0
#
#                                          DIAGNOSIS_TEXT
# 8423  coronary artery disease sda aortic valve repla...
#
# [1 rows x 24 columns]

# %%
X_test_reset[X_test_reset['index']==ex_dict['urgent']]
# Out:
#        index SUBJECT_ID   HADM_ID ICUSTAY_ID           ADMITTIME  \
# 17523  10547       5285  127903.0     259613 2202-09-22 07:15:00
#
#                 CHARTTIME              INTIME GENDER ADMIT_AGE ADMISSION_TYPE  \
# 17523 2202-09-23 14:45:00 2202-09-24 12:02:26      F        60       ELECTIVE
#
#        ... MARITAL_STATUS ETHNICITY  \
# 17523  ...        MARRIED     WHITE
#
#                                                DIAGNOSIS  \
# 17523  coronary artery disease sda aortic valve repla...
#
#                                                     TEXT DBSOURCE     LOS  \
# 17523    carotid series complete clip clip number rad...  carevue  4.2838
#
#       DAYS_EVENT_TO_ICU ICU_URGENCY SAMEDAY_EVENT_TO_ICU  \
# 17523          0.887106      urgent                    1
#
#                                           DIAGNOSIS_TEXT
# 17523  coronary artery disease sda aortic valve repla...
#
# [1 rows x 24 columns]

# %%
X_test_reset[X_test_reset['index']==ex_dict['immediate']]
# Out:
#      index SUBJECT_ID   HADM_ID ICUSTAY_ID           ADMITTIME  \
# 165   8065       3986  103534.0     200718 2146-05-12 18:28:59
#
#               CHARTTIME              INTIME GENDER ADMIT_AGE ADMISSION_TYPE  \
# 165 2146-05-12 09:50:00 2146-05-12 18:30:10      M        66      EMERGENCY
#
#      ... MARITAL_STATUS ETHNICITY DIAGNOSIS TEXT DBSOURCE     LOS  \
# 165  ...        MARRIED     WHITE  aneurysm       carevue  5.0752
#
#     DAYS_EVENT_TO_ICU ICU_URGENCY SAMEDAY_EVENT_TO_ICU  DIAGNOSIS_TEXT
# 165           0.00081   immediate                    1       aneurysm
#
# [1 rows x 24 columns]

# %%
y_pred[110], y_pred[8423], y_pred[17523], y_pred[165]
# Out:
# (4.877959077894241, 4.022171011115424, 4.037218922113228, 5.18970092460429)
